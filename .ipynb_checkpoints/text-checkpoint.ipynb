# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# from write_subtitle import write_subtitle

# %%
pattern = r'\d+\n[\d,:]+ --> [\d,:]+'
pattern1 = r'<.+?>'
# write_subtitle('house of cardsS101.txt')

# %%
# def write_subtitle(filename):
#     """import the re package."""
#     import re

#     """creat the re pattern"""
#     pattern = r'\d+\n[\d,:]+ --> [\d,:]+'
#     pattern1 = r'<(font.+\/font)>'

#     """open file and read it, then use re module to re-write it. then format the result"""
#     with open(filename, 'r+', encoding="utf-8") as f:
#         read_string = f.read()
#         re_string = re.sub(pattern, '', read_string)
#         re_string_font = re.sub(pattern1, '', re_string)
#         new_string = re_string_font.replace("\n", " ").replace("   ", "\n")

#     """create new file and filled with the "new_string" that re-writed-formatted above."""
#     with open('new_' + filename.replace(filename.split('.')[-1], 'md'), 'w', encoding="utf-8") as f:
#         f.write(new_string)

#     return True

# %%
# write_subtitle('[English] How AI Could Empower Any Business Andrew Ng TED [DownSub.com].srt')

# %%
import re
prog = re.compile(pattern)
prog
# Out:
# re.compile(r'\d+\n[\d,:]+ --> [\d,:]+', re.UNICODE)

# %%
with open('house of cardsS101.txt', 'r+', encoding="utf-8") as f:
    read_string = f.read()
    re_string = re.sub(prog, '', read_string)
    


result = prog.match(read_string)
result

r = re.match(pattern, read_string)
r
# Out:
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>

# %%
result == r
result is r
# Out:
# False
# False

# %% [markdown]
# ## Python `re`

# %%
# re.search 寻找第一个匹配的
re.search(pattern, read_string)
prog.search(read_string)

# re.match用于匹配字符串开头的re
re.match(pattern, read_string)
prog.match(read_string)
# Out:
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>

# %%
r1 = """
1
00:00:02,800 --> 00:00:05,874
"""
print(re.fullmatch(prog, r1))
# Out:
# None

# %%
prog.findall(read_string)
# Out:
# ['1\n00:00:16,200 --> 00:00:17,634',
#  '2\n00:00:21,880 --> 00:00:24,520',
#  '3\n00:00:24,600 --> 00:00:26,671',
#  '4\n00:00:26,760 --> 00:00:28,080',
#  '5\n00:00:28,200 --> 00:00:29,475',
#  '6\n00:00:29,560 --> 00:00:30,880',
#  '7\n00:00:30,960 --> 00:00:32,030',
#  '8\n00:00:44,360 --> 00:00:45,714',
#  '9\n00:00:48,920 --> 00:00:51,151',
#  '10\n00:00:51,280 --> 00:00:53,272',
#  '11\n00:00:53,360 --> 00:00:57,240',
#  '12\n00:00:58,680 --> 00:01:01,320',
#  '13\n00:01:03,240 --> 00:01:06,517',
#  '14\n00:01:06,600 --> 00:01:09,638',
#  '15\n00:01:09,720 --> 00:01:11,473',
#  '16\n00:01:16,560 --> 00:01:18,074',
#  '17\n00:01:18,160 --> 00:01:19,640',
#  '18\n00:01:22,040 --> 00:01:24,600',
#  '19\n00:01:24,680 --> 00:01:26,911',
#  '20\n00:01:27,000 --> 00:01:30,198',
#  '21\n00:01:30,280 --> 00:01:32,158',
#  '22\n00:01:52,360 --> 00:01:53,714',
#  '23\n00:01:54,200 --> 00:01:55,270',
#  '24\n00:01:55,360 --> 00:01:57,317',
#  '25\n00:01:57,400 --> 00:01:59,710',
# ...

# %%
p = prog.finditer(read_string)
p.__next__()
p.__next__()
p.__next__()
p.__next__()
p.__next__()
# Out:
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>
# <re.Match object; span=(58, 89), match='2\n00:00:21,880 --> 00:00:24,520'>
# <re.Match object; span=(123, 154), match='3\n00:00:24,600 --> 00:00:26,671'>
# <re.Match object; span=(193, 224), match='4\n00:00:26,760 --> 00:00:28,080'>
# <re.Match object; span=(249, 280), match='5\n00:00:28,200 --> 00:00:29,475'>

# %%
# re.sub(pattern, repl, string, count=0, flags=0), repl可以是一个函数
def dashrepl(matchobj):
    if matchobj.group(0) == '-': return ' '
    else: return '-'

re.sub('-{1,2}', dashrepl, 'pro----gram-files')
re.sub(r'\sAND\s', ' & ', 'Baked Beans And Spam', flags=re.IGNORECASE)
# Out:
# 'pro--gram files'
# 'Baked Beans & Spam'

# %%
re.subn('-{1,2}', dashrepl, 'pro----gram-files')
re.subn(r'\sAND\s', ' & ', 'Baked Beans And Spam', flags=re.IGNORECASE)
re.subn(pattern, '', read_string)
# Out:
# ('pro--gram files', 3)
# ('Baked Beans & Spam', 1)
# ...

# %%
# 寻找到第一个匹配位置的
prog.search(read_string, 100, 500)

# 匹配字符串开头的正则，位置可选
prog.match(read_string)

# 匹配字符串的全部才会返回
prog.fullmatch(read_string, 0, 31)
# Out:
# <re.Match object; span=(123, 154), match='3\n00:00:24,600 --> 00:00:26,671'>
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>

# %%
prog.flags
prog.groups
prog.groupindex
prog.pattern
# Out:
# 32
# 0
# {}
# '\\d+\\n[\\d,:]+ --> [\\d,:]+'

# %%
# methods of match object
m = prog.match(read_string)
m
# Out:
# <re.Match object; span=(0, 31), match='1\n00:00:16,200 --> 00:00:17,634'>

# %%
m.group()
# Out:
# '1\n00:00:16,200 --> 00:00:17,634'

# %% [markdown]
# ## master regex
